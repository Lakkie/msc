# %% [markdown]
# # 1.数学分析 Mathematical Analysis

# %% [markdown]
# 数学分析主要由微积分和级数理论组成，它所研究的主要对象是实函数，即以实数为自变量并且在实数中取值的函数。

# %% [markdown]
# ‌数学分析‌（Mathematical Analysis）是数学的核心分支，以 ‌极限理论‌ 为基石，系统研究函数、序列、级数、微分和积分的性质及其应用。它通过严格的逻辑体系（如 ‌ε-δ epsilon-delta语言‌），将微积分学从直观的几何与物理描述上升为抽象的理论框架，并为现代数学的诸多领域（如实分析、泛函分析、微分方程等）提供基础工具。

# %%
import unicodedata
from IPython.display import Image, display

# %% [markdown]
# ## 1.1 函数 Function

# %%
display(Image('pic/MA-Definition1.1.1.png'))

# %%
display(Image('pic/MA-Theorem1.1.1.png'))

# %%
display(Image('pic/MA-Definition1.1.2.png'))

# %%
display(Image('pic/MA-Theorem1.1.2.png'))

# %%
display(Image('pic/MA-Definition1.2.1.png'))

# %% [markdown]
# ## 1.2 序列 Sequence

# %%
display(Image('pic/MA-Definition-Sequence.png'))

# %% [markdown]
# ## 1.3 极限 Limit

# %% [markdown]
# ### 1.3.1 序列的极限 Limits of Sequences

# %%
display(Image('pic/MA-Definition2.1.1.png'))

# %%
display(Image('pic/MA-Definition2.1.2.png'))

# %%
display(Image('pic/MA-Theorem2.1.1.png'))

# %%
display(Image('pic/MA-Definition2.1.3.png'))

# %%
display(Image('pic/MA-Theorem2.1.2.png'))

# %% [markdown]
# ### 1.3.2 函数的极限

# %% [markdown]
# ### 1.1.5 导数 Derivative

# %% [markdown]
# ### 1.1.6 驻点 Stationary Point
# 临界点 Critical Point

# %% [markdown]
# ### 1.1.0 集合 Set

# %% [markdown]
# 元素 Element
# 子集 Subset
# 真子集 Proper Subset
# 非空真子集 Nonvoid Proper Subset
# 空集 Empty Set
# 全集 Universal Set
# 基本集 Basic Set
# 补集 Complement Set
#
# 并 Union
# 交 Intersection
# 差 Difference
# 对称差 Symmetric Difference

# %% [markdown]
# ### 1.1.1 映射 Mapping

# %% [markdown]
# 单射的 Injective
# 满射的 Surjective
# 双射的 Bijective

# %% [markdown]
# ### 1.1.2 数列 Sequence

# %% [markdown]
# 定义域 Domain
# 值域 Range

# %% [markdown]
# ### 1.1.5 无穷小 Infinitesimal

# %% [markdown]
# ### 1.1.6 无穷大 Infinity

# %%
print(f"无穷大：{unicodedata.lookup('INFINITY')}")

# %% [markdown]
# ### 1.1.7 连续性 Continuity

# %% [markdown]
# ### 9.9.9 术语 Terminology

# %% [markdown]
# 定义 Definition
# 定理 Theorem
# 引理 Lemma
# 推论 Corollary
# 公理 Axiom
# 证明 Proof
# 假设 Hypothesis
# 方程 Equation
# 不等式 Inequality
